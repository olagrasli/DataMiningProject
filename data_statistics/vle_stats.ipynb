# %%
import pandas as pd
import numpy as np
import glob

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data into panda-frames and inspect

# %%
filenames = glob.glob("../data/*")

# %%
dataframes = []
for i, filename in enumerate(filenames): 
    print(i, filename.split("/")[-1])
    df = pd.read_csv(filename)
    dataframes.append(df)
    display(df)
# Out:
# 0 studentAssessment.csv
#         id_assessment  id_student  date_submitted  is_banked  score
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0
#
# [173912 rows x 5 columns]
# 1 studentInfo.csv
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
#            highest_education imd_band age_band  num_of_prev_attempts  \
# 0           HE Qualification  90-100%     55<=                     0
# 1           HE Qualification   20-30%    35-55                     0
# 2      A Level or Equivalent   30-40%    35-55                     0
# 3      A Level or Equivalent   50-60%    35-55                     0
# 4         Lower Than A Level   50-60%     0-35                     0
# ...                      ...      ...      ...                   ...
# 32588     Lower Than A Level    10-20     0-35                     0
# 32589     Lower Than A Level   40-50%    35-55                     0
# 32590  A Level or Equivalent   20-30%     0-35                     0
# 32591     Lower Than A Level  90-100%    35-55                     0
# 32592       HE Qualification   50-60%    35-55                     0
#
#        studied_credits disability final_result
# 0                  240          N         Pass
# 1                   60          N         Pass
# 2                   60          Y    Withdrawn
# 3                   60          N         Pass
# 4                   60          N         Pass
# ...                ...        ...          ...
# 32588               30          N         Fail
# 32589               30          N  Distinction
# 32590               30          Y         Pass
# 32591               30          N    Withdrawn
# 32592               30          N  Distinction
#
# [32593 rows x 12 columns]
# 2 courses.csv
#    code_module code_presentation  module_presentation_length
# 0          AAA             2013J                         268
# 1          AAA             2014J                         269
# 2          BBB             2013J                         268
# 3          BBB             2014J                         262
# 4          BBB             2013B                         240
# 5          BBB             2014B                         234
# 6          CCC             2014J                         269
# 7          CCC             2014B                         241
# 8          DDD             2013J                         261
# 9          DDD             2014J                         262
# 10         DDD             2013B                         240
# 11         DDD             2014B                         241
# 12         EEE             2013J                         268
# 13         EEE             2014J                         269
# 14         EEE             2014B                         241
# 15         FFF             2013J                         268
# 16         FFF             2014J                         269
# 17         FFF             2013B                         240
# 18         FFF             2014B                         241
# 19         GGG             2013J                         261
# 20         GGG             2014J                         269
# 21         GGG             2014B                         241
# 3 assessments.csv
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           AAA             2013J           1752             TMA   19.0
# 1           AAA             2013J           1753             TMA   54.0
# 2           AAA             2013J           1754             TMA  117.0
# 3           AAA             2013J           1755             TMA  166.0
# 4           AAA             2013J           1756             TMA  215.0
# ..          ...               ...            ...             ...    ...
# 201         GGG             2014J          37443             CMA  229.0
# 202         GGG             2014J          37435             TMA   61.0
# 203         GGG             2014J          37436             TMA  124.0
# 204         GGG             2014J          37437             TMA  173.0
# 205         GGG             2014J          37444            Exam  229.0
#
#      weight
# 0      10.0
# 1      20.0
# 2      20.0
# 3      20.0
# 4      30.0
# ..      ...
# 201     0.0
# 202     0.0
# 203     0.0
# 204     0.0
# 205   100.0
#
# [206 rows x 6 columns]
# 4 studentVle.csv
#          code_module code_presentation  id_student  id_site  date  sum_click
# 0                AAA             2013J       28400   546652   -10          4
# 1                AAA             2013J       28400   546652   -10          1
# 2                AAA             2013J       28400   546652   -10          1
# 3                AAA             2013J       28400   546614   -10         11
# 4                AAA             2013J       28400   546714   -10          1
# ...              ...               ...         ...      ...   ...        ...
# 10655275         GGG             2014J      675811   896943   269          3
# 10655276         GGG             2014J      675578   896943   269          1
# 10655277         GGG             2014J      654064   896943   269          3
# 10655278         GGG             2014J      654064   896939   269          1
# 10655279         GGG             2014J      654064   896939   269          1
#
# [10655280 rows x 6 columns]
# 5 vle.csv
#       id_site code_module code_presentation activity_type  week_from  week_to
# 0      546943         AAA             2013J      resource        NaN      NaN
# 1      546712         AAA             2013J     oucontent        NaN      NaN
# 2      546998         AAA             2013J      resource        NaN      NaN
# 3      546888         AAA             2013J           url        NaN      NaN
# 4      547035         AAA             2013J      resource        NaN      NaN
# ...       ...         ...               ...           ...        ...      ...
# 6359   897063         GGG             2014J      resource        NaN      NaN
# 6360   897109         GGG             2014J      resource        NaN      NaN
# 6361   896965         GGG             2014J     oucontent        NaN      NaN
# 6362   897060         GGG             2014J      resource        NaN      NaN
# 6363   897100         GGG             2014J      resource        NaN      NaN
#
# [6364 rows x 6 columns]
# 6 studentRegistration.csv
#       code_module code_presentation  id_student  date_registration  \
# 0             AAA             2013J       11391             -159.0
# 1             AAA             2013J       28400              -53.0
# 2             AAA             2013J       30268              -92.0
# 3             AAA             2013J       31604              -52.0
# 4             AAA             2013J       32885             -176.0
# ...           ...               ...         ...                ...
# 32588         GGG             2014J     2640965               -4.0
# 32589         GGG             2014J     2645731              -23.0
# 32590         GGG             2014J     2648187             -129.0
# 32591         GGG             2014J     2679821              -49.0
# 32592         GGG             2014J     2684003              -28.0
#
#        date_unregistration
# 0                      NaN
# 1                      NaN
# 2                     12.0
# 3                      NaN
# 4                      NaN
# ...                    ...
# 32588                  NaN
# 32589                  NaN
# 32590                  NaN
# 32591                101.0
# 32592                  NaN
#
# [32593 rows x 5 columns]

# %%
studentAssesment_df = dataframes[0]
studentInfo_df = dataframes[1]
courses_df = dataframes[2]
assesments_df = dataframes[3]
studentVle_df = dataframes[4]
vle_df = dataframes[5]
studentRegistration_df = dataframes[6]

# %% [markdown]
# ## Make VLE statistics

# %%
def plot_vle_student_timeline(student_id, moduleStudentVle, code_module, code_presentation, assessment_type): 
    oneStudentVle = moduleStudentVle.loc[student_id, :]

    daily_clicks = []
    for day in sorted(list(set(oneStudentVle['date']))): 
        sum_clicks = sum(oneStudentVle[oneStudentVle['date'] == day]['sum_click'])
        daily_clicks.append((day, sum_clicks))

    x, y = [day[0] for day in daily_clicks], [day[1] for day in daily_clicks]

    # find assesment day
    asses_bool = (assesments_df['code_module']==code_module)&(assesments_df['code_presentation']==code_presentation)&(assesments_df['assessment_type']==assessment_type)
    assessment_days = list(assesments_df[asses_bool]['date'])
    assessment_ids = list(assesments_df[asses_bool]['id_assessment'])
    assessment_scores = list([(studentAssesment_df[(studentAssesment_df['id_student']==student_id)&(studentAssesment_df['id_assessment']==assessment_id)]['score']) for assessment_id in assessment_ids])
    
    # find exam result 
    #exam_id = int(assesments_df[ (assesments_df['code_module']==code_module)&(assesments_df['code_presentation']==code_presentation)&(assesments_df['assessment_type']=='Exam')]['id_assessment'])
    #print(exam_id)
    #exam_result = studentAssesment_df[(studentAssesment_df['id_student']==student_id)&(studentAssesment_df['id_assessment']==exam_id)]['score']
    #print("Exam result", exam_result)
    
    # find course length
    course_length = int(courses_df[(courses_df['code_module']==code_module)&(courses_df['code_presentation']==code_presentation)]['module_presentation_length'])
    
    # print assessment scores
    print(assessment_scores)
    
    # plot
    plt.figure(figsize=(8,3))
    plt.scatter(x,y, s=8)
    plt.scatter(assessment_days, [100 for i in range(len(assessment_days))], c='r', s=50)
    plt.scatter([course_length], [100], s=60, c='y')
    plt.show()
    
    return 0

# %%
#studentVle_df = studentVle_df.set_index('id_student')

# %%
code_module = 'DDD'
code_presentation = '2013J'
assessment_type = 'TMA'

# %%
moduleStudentVle = studentVle_df[(studentVle_df['code_module']==code_module)&(studentVle_df['code_presentation']==code_presentation)]

# %%
students_taking_module = list(set(moduleStudentVle.index))

# %%
for student_id in students_taking_module[:10]: 
    try: 
        plot_vle_student_timeline(student_id, moduleStudentVle, code_module, code_presentation, assessment_type)
    except: 
        print(student_id)
# Out:
# [76177    90.0
# Name: score, dtype: float64, 78190    77.0
# Name: score, dtype: float64, 78351    84.0
# Name: score, dtype: float64, 80070    88.0
# Name: score, dtype: float64, Series([], Name: score, dtype: float64), Series([], Name: score, dtype: float64)]
# [76190    77.0
# Name: score, dtype: float64, 78200    61.0
# Name: score, dtype: float64, 78360    75.0
# Name: score, dtype: float64, Series([], Name: score, dtype: float64), Series([], Name: score, dtype: float64), Series([], Name: score, dtype: float64)]
# [75630    80.0
# Name: score, dtype: float64, 77704    68.0
# Name: score, dtype: float64, 79118    73.0
# Name: score, dtype: float64, 79637    42.0
# Name: score, dtype: float64, 81171    18.0
# Name: score, dtype: float64, Series([], Name: score, dtype: float64)]
# [76416    97.0
# Name: score, dtype: float64, 77087    89.0
# Name: score, dtype: float64, 78548    90.0
# Name: score, dtype: float64, 80238    94.0
# Name: score, dtype: float64, 80711    86.0
# Name: score, dtype: float64, 81765    71.0
# Name: score, dtype: float64]
# [76721    68.0
# Name: score, dtype: float64, 77356    70.0
# Name: score, dtype: float64, 78796    86.0
# Name: score, dtype: float64, 80465    24.0
# Name: score, dtype: float64, 80911    31.0
# Name: score, dtype: float64, 81934    25.0
# Name: score, dtype: float64]
# [75933    76.0
# Name: score, dtype: float64, 77977    82.0
# Name: score, dtype: float64, 79374    85.0
# Name: score, dtype: float64, 79876    87.0
# Name: score, dtype: float64, 81385    80.0
# Name: score, dtype: float64, 82348    75.0
# Name: score, dtype: float64]
# [75934    65.0
# Name: score, dtype: float64, 77978    75.0
# Name: score, dtype: float64, 79375    69.0
# Name: score, dtype: float64, 79877    74.0
# Name: score, dtype: float64, 81386    67.0
# Name: score, dtype: float64, 82349    42.0
# Name: score, dtype: float64]
# [76275    90.0
# Name: score, dtype: float64, 78275    77.0
# Name: score, dtype: float64, 78428    83.0
# Name: score, dtype: float64, 80140    76.0
# Name: score, dtype: float64, 81602    63.0
# Name: score, dtype: float64, Series([], Name: score, dtype: float64)]
# 2662451
# [75831    73.0
# Name: score, dtype: float64, 77886    62.0
# Name: score, dtype: float64, 79288    78.0
# Name: score, dtype: float64, 79798    43.0
# Name: score, dtype: float64, 81310    78.0
# Name: score, dtype: float64, 82287    69.0
# Name: score, dtype: float64]
