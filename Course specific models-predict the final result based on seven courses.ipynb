# %%
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
clicks_df = pd.read_csv('/content/drive/My Drive/Data mining/stud_dates_click.csv')
clicks_df
# Out:
#       code_module code_presentation  id_student  ...  267  268  269
# 0             AAA             2013J       11391  ...  0.0  0.0  0.0
# 1             AAA             2013J       28400  ...  0.0  0.0  0.0
# 2             AAA             2013J       30268  ...  0.0  0.0  0.0
# 3             AAA             2013J       31604  ...  0.0  0.0  0.0
# 4             AAA             2013J       32885  ...  0.0  0.0  0.0
# ...           ...               ...         ...  ...  ...  ...  ...
# 32588         GGG             2014J     2640965  ...  0.0  0.0  0.0
# 32589         GGG             2014J     2645731  ...  0.0  0.0  0.0
# 32590         GGG             2014J     2648187  ...  0.0  0.0  0.0
# 32591         GGG             2014J     2679821  ...  0.0  0.0  0.0
# 32592         GGG             2014J     2684003  ...  0.0  0.0  0.0
#
# [32593 rows x 299 columns]

# %%
stud_df = pd.read_csv('/content/drive/My Drive/Data mining/studentInfo.csv')
stud_df
# Out:
#       code_module code_presentation  ...  disability final_result
# 0             AAA             2013J  ...           N         Pass
# 1             AAA             2013J  ...           N         Pass
# 2             AAA             2013J  ...           Y    Withdrawn
# 3             AAA             2013J  ...           N         Pass
# 4             AAA             2013J  ...           N         Pass
# ...           ...               ...  ...         ...          ...
# 32588         GGG             2014J  ...           N         Fail
# 32589         GGG             2014J  ...           N  Distinction
# 32590         GGG             2014J  ...           Y         Pass
# 32591         GGG             2014J  ...           N    Withdrawn
# 32592         GGG             2014J  ...           N  Distinction
#
# [32593 rows x 12 columns]

# %%
# merge three table for further processing
data = pd.merge(stud_df, clicks_df, on=['code_module', 'code_presentation', 'id_student', 'final_result'], how='inner')
data
# Out:
#       code_module code_presentation  id_student gender  ...  266  267  268  269
# 0             AAA             2013J       11391      M  ...  0.0  0.0  0.0  0.0
# 1             AAA             2013J       28400      F  ...  0.0  0.0  0.0  0.0
# 2             AAA             2013J       30268      F  ...  0.0  0.0  0.0  0.0
# 3             AAA             2013J       31604      F  ...  0.0  0.0  0.0  0.0
# 4             AAA             2013J       32885      F  ...  0.0  0.0  0.0  0.0
# ...           ...               ...         ...    ...  ...  ...  ...  ...  ...
# 32588         GGG             2014J     2640965      F  ...  0.0  0.0  0.0  0.0
# 32589         GGG             2014J     2645731      F  ...  0.0  0.0  0.0  0.0
# 32590         GGG             2014J     2648187      F  ...  0.0  0.0  0.0  0.0
# 32591         GGG             2014J     2679821      F  ...  0.0  0.0  0.0  0.0
# 32592         GGG             2014J     2684003      F  ...  0.0  0.0  0.0  0.0
#
# [32593 rows x 307 columns]

# %%
# no of records based on course
data['code_module'].value_counts()
# Out:
# BBB    7909
# FFF    7762
# DDD    6272
# CCC    4434
# EEE    2934
# GGG    2534
# AAA     748
# Name: code_module, dtype: int64

# %%
# change the label of target
data['final_result'] = data['final_result'].map({'Pass':1, 'Distinction':1, 'Withdrawn':0, 'Fail':0})

# split the data into train and test
dataX = data.drop(columns='final_result')
target = data['final_result']
X_train, X_test, y_train, y_test = train_test_split(dataX, target, test_size=0.2, stratify=target)

# %%
X_train['code_module'].value_counts(), X_test['code_module'].value_counts()
# Out:
# (BBB    6320
#  FFF    6228
#  DDD    4975
#  CCC    3549
#  EEE    2342
#  GGG    2049
#  AAA     611
#  Name: code_module, dtype: int64, BBB    1589
#  FFF    1534
#  DDD    1297
#  CCC     885
#  EEE     592
#  GGG     485
#  AAA     137
#  Name: code_module, dtype: int64)

# %%
X_train['result'] = y_train

# course AAA
aX = X_train.query('code_module=="AAA"')
a_y = aX['result']

# course BBB
bX = X_train.query('code_module=="BBB"')
b_y = bX['result']

# course CCC
cX = X_train.query('code_module=="CCC"')
c_y = cX['result']

# course DDD
dX = X_train.query('code_module=="DDD"')
d_y = dX['result']

# course EEE
eX = X_train.query('code_module=="EEE"')
e_y = eX['result']

# course FFF
fX = X_train.query('code_module=="FFF"')
f_y = fX['result']

# course GGG
gX = X_train.query('code_module=="GGG"')
g_y = gX['result']

# %%
def prepare_data(X, rule='W'):
    
    #clicks data
    cols = [str(i) for i in range(-25, 250)]
    X1 = X[cols]
    X1 = X1.T
    X1.index = pd.date_range(start='1/1/2014', periods=275)
    X1 = X1.resample(rule).sum()
    X1 = X1.T
    
    # code_module
    course = X['code_module']
            
    return X1, course

def visualize_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.legend(['Train', 'Validation'])
    plt.show()

# %%
# prepare the data
ax, _ = prepare_data(aX)
bx, _ = prepare_data(bX)
cx, _ = prepare_data(cX)
dx, _ = prepare_data(dX)
ex, _ = prepare_data(eX)
fx, _ = prepare_data(fX)
gx, _ = prepare_data(gX)

X_test_clicks, courses = prepare_data(X_test)

# print stastic
print('Train Data:', ax.shape, bx.shape, cx.shape)
print('Test Data: ', X_test_clicks.shape)
print('Test target count:', Counter(y_test))
# Out:
# Train Data: (611, 40) (6320, 40) (3549, 40)
# Test Data:  (6519, 40)
# Test target count: Counter({0: 3442, 1: 3077})

# %%
from tensorflow.keras.layers import Dense, Input, Conv1D, AveragePooling1D, BatchNormalization, Flatten, Add, Multiply, Softmax, LSTM
from tensorflow.keras import layers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import Sequential, Model

# %%
# Define ann model
def ann_model():
    ann = Sequential()
    ann.add(Input(shape=(ax.shape[1], )))
    ann.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    ann.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    ann.add(Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    ann.add(Dense(1, activation='sigmoid'))
    # compile the model
    ann.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return ann

# define cnn model
def cnn_model():
    cnn = Sequential()
    cnn.add(Input(shape=(ax.shape[1], 1)))
    cnn.add(Conv1D(16, kernel_size=2, activation='relu'))
    cnn.add(BatchNormalization())
    cnn.add(AveragePooling1D(2))
    cnn.add(Conv1D(32, kernel_size=2, activation='relu'))
    cnn.add(BatchNormalization())
    cnn.add(AveragePooling1D(2))
    cnn.add(Flatten())
    cnn.add(Dense(128,  activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    cnn.add(Dense(64,  activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    cnn.add(Dense(32,  activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    cnn.add(Dense(1,  activation='sigmoid'))
    # compile the model
    cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return cnn

# define lstm model
def lstm_model():
    lstm = Sequential()
    lstm.add(LSTM(25, activation='relu', input_shape=(ax.shape[1],1), return_sequences=True, kernel_regularizer=regularizers.l2(0.01)))
    lstm.add(LSTM(10, activation='relu', return_sequences=False, kernel_regularizer=regularizers.l2(0.01)))
    lstm.add(Dense(1, activation='sigmoid'))
    # compile the model
    lstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return lstm

# %%
path1 = '/content/drive/My Drive/Data mining/model/course_model_1.h5'
callbacks = ModelCheckpoint(path1, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model1 = ann_model()
hist = model1.fit(ax, a_y, validation_split=0.1, epochs=20, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path2 = '/content/drive/My Drive/Data mining/model/course_model_2.h5'
callbacks = ModelCheckpoint(path2, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model2 = ann_model()
hist = model2.fit(bx, b_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path3 = '/content/drive/My Drive/Data mining/model/course_model_3.h5'
callbacks = ModelCheckpoint(path3, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model3 = ann_model()
hist = model3.fit(cx, c_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path4 = '/content/drive/My Drive/Data mining/model/course_model_4.h5'
callbacks = ModelCheckpoint(path4, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model4 = ann_model()
hist = model4.fit(dx, d_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path5 = '/content/drive/My Drive/Data mining/model/course_model_5.h5'
callbacks = ModelCheckpoint(path5, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model5 = ann_model()
hist = model5.fit(ex, e_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path6 = '/content/drive/My Drive/Data mining/model/course_model_6.h5'
callbacks = ModelCheckpoint(path6, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model6 = ann_model()
hist = model6.fit(fx, f_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path7 = '/content/drive/My Drive/Data mining/model/course_model_7.h5'
callbacks = ModelCheckpoint(path7, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model7 = ann_model()
hist = model7.fit(gx, g_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

# %%
prediction = []

# load model
model1.load_weights(path1)
model2.load_weights(path2)
model3.load_weights(path3)
model4.load_weights(path4)
model5.load_weights(path5)
model6.load_weights(path6)
model7.load_weights(path7)

for i in range(len(X_test_clicks)):
    cm = courses.iloc[i]
    if cm=='AAA':        
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, -1)
        prediction.append(model1.predict(test)[0][0])
    elif cm=='BBB':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, -1)
        prediction.append(model2.predict(test)[0][0])
    elif cm=='CCC':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, -1)
        prediction.append(model3.predict(test)[0][0])
    elif cm=='DDD':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, -1)
        prediction.append(model4.predict(test)[0][0])
    elif cm=='EEE':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, -1)
        prediction.append(model5.predict(test)[0][0])
    elif cm=='FFF':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, -1)
        prediction.append(model6.predict(test)[0][0])
    else:
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, -1)
        prediction.append(model7.predict(test)[0][0])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0bec228dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0bfcaa0950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0bed9f6c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predict = np.array(prediction)
predict = np.where(predict>0.5, 1, 0)
print('Accuracy: ', accuracy_score(predict, y_test))

result = pd.DataFrame(classification_report(predict, y_test,output_dict=True)).T
result['accuracy'] = result.loc['accuracy', 'precision']
result = result.iloc[:2, [0,1,2,4]]
result['model'] = 'ANN'
result
# Out:
# Accuracy:  0.9151710385028379
#    precision    recall  f1-score  accuracy model
# 0   0.887856  0.948185  0.917029  0.915171   ANN
# 1   0.945726  0.882888  0.913228  0.915171   ANN

# %% [markdown]
# # change data dimension

# %%
# change the dimension
ax = ax.to_numpy().reshape(ax.shape[0], ax.shape[1], 1)
bx = bx.to_numpy().reshape(bx.shape[0], bx.shape[1], 1)
cx = cx.to_numpy().reshape(cx.shape[0], cx.shape[1], 1)
dx = dx.to_numpy().reshape(dx.shape[0], dx.shape[1], 1)
ex = ex.to_numpy().reshape(ex.shape[0], ex.shape[1], 1)
fx = fx.to_numpy().reshape(fx.shape[0], fx.shape[1], 1)
gx = gx.to_numpy().reshape(gx.shape[0], gx.shape[1], 1)

# %% [markdown]
# # CNN base model

# %%
path1 = '/content/drive/My Drive/Data mining/model/course_model_1.h5'
callbacks = ModelCheckpoint(path1, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model1 = cnn_model()
hist = model1.fit(ax, a_y, validation_split=0.1, epochs=20, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path2 = '/content/drive/My Drive/Data mining/model/course_model_2.h5'
callbacks = ModelCheckpoint(path2, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model2 = cnn_model()
hist = model2.fit(bx, b_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path3 = '/content/drive/My Drive/Data mining/model/course_model_3.h5'
callbacks = ModelCheckpoint(path3, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model3 = cnn_model()
hist = model3.fit(cx, c_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path4 = '/content/drive/My Drive/Data mining/model/course_model_4.h5'
callbacks = ModelCheckpoint(path4, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model4 = cnn_model()
hist = model4.fit(dx, d_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path5 = '/content/drive/My Drive/Data mining/model/course_model_5.h5'
callbacks = ModelCheckpoint(path5, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model5 = cnn_model()
hist = model5.fit(ex, e_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path6 = '/content/drive/My Drive/Data mining/model/course_model_6.h5'
callbacks = ModelCheckpoint(path6, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model6 = cnn_model()
hist = model6.fit(fx, f_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path7 = '/content/drive/My Drive/Data mining/model/course_model_7.h5'
callbacks = ModelCheckpoint(path7, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model7 = cnn_model()
hist = model7.fit(gx, g_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

# %%
prediction = []

# load model
model1.load_weights(path1)
model2.load_weights(path2)
model3.load_weights(path3)
model4.load_weights(path4)
model5.load_weights(path5)
model6.load_weights(path6)
model7.load_weights(path7)

for i in range(len(X_test_clicks)):
    cm = courses.iloc[i]
    if cm=='AAA':        
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model1.predict(test)[0][0])
    elif cm=='BBB':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model2.predict(test)[0][0])
    elif cm=='CCC':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model3.predict(test)[0][0])
    elif cm=='DDD':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model4.predict(test)[0][0])
    elif cm=='EEE':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model5.predict(test)[0][0])
    elif cm=='FFF':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model6.predict(test)[0][0])
    else:
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model7.predict(test)[0][0])
# Out:
# WARNING:tensorflow:5 out of the last 6513 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0bec02eb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6514 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0be8b5b9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 6519 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0be8b50050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0be8aa58c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predict = np.array(prediction)
predict = np.where(predict>0.5, 1, 0)
print('Accuracy: ', accuracy_score(predict, y_test))

# store and concat with result
r = pd.DataFrame(classification_report(predict, y_test,output_dict=True)).T
r['accuracy'] = r.loc['accuracy', 'precision']
r = r.iloc[:2, [0,1,2,4]]
r['model'] = 'CNN'

result = pd.concat([result, r])
result
# Out:
# Accuracy:  0.9259088817303267
#    precision    recall  f1-score  accuracy model
# 0   0.887856  0.948185  0.917029  0.915171   ANN
# 1   0.945726  0.882888  0.913228  0.915171   ANN
# 0   0.873620  0.984288  0.925658  0.925909   CNN
# 1   0.984400  0.874423  0.926158  0.925909   CNN

# %% [markdown]
# #LSTM

# %%
path1 = '/content/drive/My Drive/Data mining/model/course_model_1.h5'
callbacks = ModelCheckpoint(path1, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model1 = lstm_model()
hist = model1.fit(ax, a_y, validation_split=0.1, epochs=20, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path2 = '/content/drive/My Drive/Data mining/model/course_model_2.h5'
callbacks = ModelCheckpoint(path2, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model2 = lstm_model()
hist = model2.fit(bx, b_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path3 = '/content/drive/My Drive/Data mining/model/course_model_3.h5'
callbacks = ModelCheckpoint(path3, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model3 = lstm_model()
hist = model3.fit(cx, c_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path4 = '/content/drive/My Drive/Data mining/model/course_model_4.h5'
callbacks = ModelCheckpoint(path4, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model4 = lstm_model()
hist = model4.fit(dx, d_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path5 = '/content/drive/My Drive/Data mining/model/course_model_5.h5'
callbacks = ModelCheckpoint(path5, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model5 = lstm_model()
hist = model5.fit(ex, e_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path6 = '/content/drive/My Drive/Data mining/model/course_model_6.h5'
callbacks = ModelCheckpoint(path6, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model6 = lstm_model()
hist = model6.fit(fx, f_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

path7 = '/content/drive/My Drive/Data mining/model/course_model_7.h5'
callbacks = ModelCheckpoint(path7, save_best_only=True, save_weights_only=True, mode='max', monitor='val_accuracy', verbose=0)
model7 = lstm_model()
hist = model7.fit(gx, g_y, validation_split=0.1, epochs=15, batch_size=32, verbose=0, callbacks=[callbacks])
visualize_loss(hist)

# %%
prediction = []

# load model
model1.load_weights(path1)
model2.load_weights(path2)
model3.load_weights(path3)
model4.load_weights(path4)
model5.load_weights(path5)
model6.load_weights(path6)
model7.load_weights(path7)

for i in range(len(X_test_clicks)):
    cm = courses.iloc[i]
    if cm=='AAA':        
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model1.predict(test)[0][0])
    elif cm=='BBB':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model2.predict(test)[0][0])
    elif cm=='CCC':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model3.predict(test)[0][0])
    elif cm=='DDD':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model4.predict(test)[0][0])
    elif cm=='EEE':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model5.predict(test)[0][0])
    elif cm=='FFF':
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model6.predict(test)[0][0])
    else:
        test = X_test_clicks.iloc[i, :].to_numpy().reshape(1, ax.shape[1], 1)
        prediction.append(model7.predict(test)[0][0])
# Out:
# WARNING:tensorflow:5 out of the last 6513 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0be105f7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6514 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0be0fd8c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 6519 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0be0fd8a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0be0dc89e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predict = np.array(prediction)
predict = np.where(predict>0.5, 1, 0)
print('Accuracy: ', accuracy_score(predict, y_test))

# store and concat with result
r = pd.DataFrame(classification_report(predict, y_test, output_dict=True)).T
r['accuracy'] = r.loc['accuracy', 'precision']
r = r.iloc[:2, [0,1,2,4]]
r['model'] = 'LSTM'

result = pd.concat([result, r])
result
# Out:
# Accuracy:  0.9188525847522626
#    precision    recall  f1-score  accuracy model
# 0   0.887856  0.948185  0.917029  0.915171   ANN
# 1   0.945726  0.882888  0.913228  0.915171   ANN
# 0   0.873620  0.984288  0.925658  0.925909   CNN
# 1   0.984400  0.874423  0.926158  0.925909   CNN
# 0   0.896572  0.946916  0.921057  0.918853  LSTM
# 1   0.943776  0.890798  0.916522  0.918853  LSTM
