# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style('whitegrid')

# %%
# Read the StudentInfo file
studinfo = pd.read_csv('./data/studentInfo.csv')

# %%
studinfo
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
#            highest_education imd_band age_band  num_of_prev_attempts  \
# 0           HE Qualification  90-100%     55<=                     0
# 1           HE Qualification   20-30%    35-55                     0
# 2      A Level or Equivalent   30-40%    35-55                     0
# 3      A Level or Equivalent   50-60%    35-55                     0
# 4         Lower Than A Level   50-60%     0-35                     0
# ...                      ...      ...      ...                   ...
# 32588     Lower Than A Level    10-20     0-35                     0
# 32589     Lower Than A Level   40-50%    35-55                     0
# 32590  A Level or Equivalent   20-30%     0-35                     0
# 32591     Lower Than A Level  90-100%    35-55                     0
# 32592       HE Qualification   50-60%    35-55                     0
#
#        studied_credits disability final_result
# 0                  240          N         Pass
# 1                   60          N         Pass
# 2                   60          Y    Withdrawn
# 3                   60          N         Pass
# 4                   60          N         Pass
# ...                ...        ...          ...
# 32588               30          N         Fail
# 32589               30          N  Distinction
# 32590               30          Y         Pass
# 32591               30          N    Withdrawn
# 32592               30          N  Distinction
#
# [32593 rows x 12 columns]

# %%
studinfo = studinfo.replace("Distinction", "Pass").replace("Withdrawn", "Fail")
studinfo
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
#            highest_education imd_band age_band  num_of_prev_attempts  \
# 0           HE Qualification  90-100%     55<=                     0
# 1           HE Qualification   20-30%    35-55                     0
# 2      A Level or Equivalent   30-40%    35-55                     0
# 3      A Level or Equivalent   50-60%    35-55                     0
# 4         Lower Than A Level   50-60%     0-35                     0
# ...                      ...      ...      ...                   ...
# 32588     Lower Than A Level    10-20     0-35                     0
# 32589     Lower Than A Level   40-50%    35-55                     0
# 32590  A Level or Equivalent   20-30%     0-35                     0
# 32591     Lower Than A Level  90-100%    35-55                     0
# 32592       HE Qualification   50-60%    35-55                     0
#
#        studied_credits disability final_result
# 0                  240          N         Pass
# 1                   60          N         Pass
# 2                   60          Y         Fail
# 3                   60          N         Pass
# 4                   60          N         Pass
# ...                ...        ...          ...
# 32588               30          N         Fail
# 32589               30          N         Pass
# 32590               30          Y         Pass
# 32591               30          N         Fail
# 32592               30          N         Pass
#
# [32593 rows x 12 columns]

# %% [markdown]
# # Null value check

# %%
studinfo.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %% [markdown]
# # check the final result

# %%
studinfo.groupby('final_result')['id_student'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='final_result'>

# %%
total = studinfo.groupby(['final_result'],as_index = False)
total = total['id_student'].count()
total
# Out:
#   final_result  id_student
# 0         Fail       17208
# 1         Pass       15385

# %% [markdown]
# # Results based on Gender

# %%
gender = studinfo.groupby(['gender'],as_index = False)
gender_count = gender['id_student'].count()
gender_count
# Out:
#   gender  id_student
# 0      F       14718
# 1      M       17875

# %%
result_gender = studinfo.groupby(['gender', 'final_result'],as_index = False)
result_gender_count = result_gender['id_student'].count()
result_gender_count
# Out:
#   gender final_result  id_student
# 0      F         Fail        7589
# 1      F         Pass        7129
# 2      M         Fail        9619
# 3      M         Pass        8256

# %%
result_gender = studinfo.groupby(['gender', 'final_result'],as_index = False)

result_gender_count = result_gender['id_student'].count()
result_gender_count
# Out:
#   gender final_result  id_student
# 0      F         Fail        7589
# 1      F         Pass        7129
# 2      M         Fail        9619
# 3      M         Pass        8256

# %%
merge = pd.merge(gender_count, result_gender_count, on = 'gender', how = 'left')
merge['i'] = round((merge['id_student_y']/merge['id_student_x']), 2)
merge = merge[['gender','final_result', 'i']]

female = merge.loc[merge['gender'] == 'F']
male = merge.loc[merge['gender'] == 'M']

fig = plt.figure() 

ax = fig.add_subplot(111) 

female.set_index('final_result',drop=True,inplace=True)
male.set_index('final_result',drop=True,inplace=True)
female.plot(kind='bar', ax=ax, width= 0.3, position=1)
male.plot(kind='bar', color='#2ca02c', ax=ax, width= 0.3, position=0)

plt.xlabel('Result Status')
plt.ylabel('Result')
plt.title('Gender vs Result')
plt.legend(['Female', 'Male'])
plt.show()

# %% [markdown]
# # Based on Region

# %%
region = studinfo.groupby(['region'],as_index = False)
region_count = region['id_student'].count()
result_region = studinfo.groupby(['region', 'final_result'],as_index = False)
result_region_count = result_region['id_student'].count()

merge = pd.merge(region_count, result_region_count , on = 'region', how = 'left')
merge['_'] = round((merge['id_student_y']/merge['id_student_x']), 2)
merge = merge[['region','final_result', '_']]

merge.set_index(['region','final_result']).unstack().plot(kind="barh", stacked=True)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

plt.ylabel('Region')
plt.xlabel('Result')
plt.title('Region vs Result')
plt.legend(['Fail','Pass'], loc='center left', bbox_to_anchor=(1, 0.85))
plt.show()

# %%
region = studinfo.groupby(['region'],as_index = False)
region_count = region['id_student'].count()
result_region = studinfo.groupby(['region', 'final_result'],as_index = False)
result_region_count = result_region['id_student'].count()
result_region_count
# Out:
#                   region final_result  id_student
# 0    East Anglian Region         Fail        1704
# 1    East Anglian Region         Pass        1636
# 2   East Midlands Region         Fail        1284
# 3   East Midlands Region         Pass        1081
# 4                Ireland         Fail         534
# 5                Ireland         Pass         650
# 6          London Region         Fail        1854
# 7          London Region         Pass        1362
# 8           North Region         Fail         902
# 9           North Region         Pass         921
# 10  North Western Region         Fail        1738
# 11  North Western Region         Pass        1168
# 12              Scotland         Fail        1759
# 13              Scotland         Pass        1687
# 14     South East Region         Fail        1024
# 15     South East Region         Pass        1087
# 16          South Region         Fail        1472
# 17          South Region         Pass        1620
# 18     South West Region         Fail        1223
# 19     South West Region         Pass        1213
# 20                 Wales         Fail        1144
# 21                 Wales         Pass         942
# 22  West Midlands Region         Fail        1464
# 23  West Midlands Region         Pass        1118
# 24      Yorkshire Region         Fail        1106
# 25      Yorkshire Region         Pass         900

# %% [markdown]
# # Based on educatio level

# %%
education = studinfo.groupby(['highest_education'],as_index = False)
education_count = education['id_student'].count()
result_education = studinfo.groupby(['highest_education', 'final_result'],as_index = False)
result_education_count = result_education['id_student'].count()

merge = pd.merge(education_count, result_education_count , on = 'highest_education', how = 'left')
merge['_'] = round((merge['id_student_y']/merge['id_student_x']), 2)
merge = merge[['highest_education','final_result', '_']]

merge.set_index(['highest_education','final_result']).unstack().plot(kind = 'barh', stacked = True)

box = ax.get_position()
# ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

plt.ylabel('Highest Education')
plt.xlabel('Result')
plt.title('Highest Education vs Result')
plt.legend(['Fail','Pass'], loc='center left', bbox_to_anchor=(1, 0.85))
plt.show()

# %% [markdown]
# # Based on IMD Band

# %%
imd = studinfo.groupby(['imd_band'],as_index = False)
imd_count = imd['id_student'].count()
result_imd = studinfo.groupby(['imd_band', 'final_result'],as_index = False)
result_imd_count = result_imd['id_student'].count()

merge = pd.merge(imd_count, result_imd_count , on = 'imd_band', how = 'left')
merge['_'] = round((merge['id_student_y']/merge['id_student_x']), 2)
merge = merge[['imd_band','final_result', '_']]

merge.set_index(['imd_band','final_result']).unstack().plot(kind="barh", stacked = True)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

plt.ylabel('IMD Band')
plt.xlabel('Result')
plt.title('IMD Band vs Result')
plt.legend(['Fail','Pass'], loc='center left', bbox_to_anchor=(1, 0.85))
plt.show()

# %%
imd = studinfo.groupby(['imd_band'],as_index = False)
imd_count = imd['id_student'].count()
result_imd = studinfo.groupby(['imd_band', 'final_result'],as_index = False)
result_imd_count = result_imd['id_student'].count()
result_imd_count
# Out:
#    imd_band final_result  id_student
# 0     0-10%         Fail        2147
# 1     0-10%         Pass        1164
# 2     10-20         Fail        2158
# 3     10-20         Pass        1358
# 4    20-30%         Fail        2165
# 5    20-30%         Pass        1489
# 6    30-40%         Fail        1879
# 7    30-40%         Pass        1660
# 8    40-50%         Fail        1739
# 9    40-50%         Pass        1517
# 10   50-60%         Fail        1600
# 11   50-60%         Pass        1524
# 12   60-70%         Fail        1397
# 13   60-70%         Pass        1508
# 14   70-80%         Fail        1396
# 15   70-80%         Pass        1483
# 16   80-90%         Fail        1269
# 17   80-90%         Pass        1493
# 18  90-100%         Fail        1077
# 19  90-100%         Pass        1459

# %% [markdown]
# # Based on age band

# %%
age = studinfo.groupby(['age_band'],as_index = False)
age_count = age['id_student'].count()
result_age = studinfo.groupby(['age_band', 'final_result'],as_index = False)
result_age_count = result_age['id_student'].count()

merge = pd.merge(age_count, result_age_count, on = 'age_band', how = 'left')
merge['_'] = round((merge['id_student_y']/merge['id_student_x']), 2)
merge = merge[['age_band','final_result', '_']]

merge.set_index(['age_band','final_result']).unstack().plot(kind = 'bar', stacked = True)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

plt.ylabel('Age')
plt.xlabel('Result')
plt.title('Age vs Result')
plt.legend(['Fail','Pass'], loc='center left', bbox_to_anchor=(1, 0.85))
plt.show()

# %% [markdown]
# # Results based on Diasability

# %%
disability_ = studinfo.groupby(['disability'],as_index = False)
disability_count = disability_['id_student'].count()
result_disability = studinfo.groupby(['disability', 'final_result'],as_index = False)
result_disability_count = result_disability['id_student'].count()

merge = pd.merge(disability_count, result_disability_count, on = 'disability', how = 'left')
merge['i'] = round((merge['id_student_y']/merge['id_student_x']), 2)
merge = merge[['disability','final_result', 'i']]

yes = merge.loc[merge['disability'] == 'Y']
no = merge.loc[merge['disability'] == 'N']

fig = plt.figure() 

ax = fig.add_subplot(111) 

yes.set_index('final_result',drop=True,inplace=True)
no.set_index('final_result',drop=True,inplace=True)
yes.plot(kind='bar', ax=ax, width= 0.3, position=1)
no.plot(kind='bar', color='#2ca02c', ax=ax, width= 0.3, position=0)

plt.xlabel('Result Status')
plt.ylabel('Result')
plt.title('Disability vs Result')
plt.legend(['Yes', 'No'])
plt.show()

# %% [markdown]
# # Student vs number of course register

# %%
scount = studinfo.groupby('id_student').count()['final_result']

# %%
scount[scount>1].sort_values(ascending=False)
# Out:
# id_student
# 584077     5
# 610287     4
# 624126     4
# 596620     4
# 548926     4
#           ..
# 554065     2
# 554205     2
# 554235     2
# 554243     2
# 2710343    2
# Name: final_result, Length: 3538, dtype: int64

# %% [markdown]
# # Student Assessment

# %%
studAssessment = pd.read_csv('./data/studentAssessment.csv')
studAssessment
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0
#
# [173912 rows x 5 columns]

# %%
studAssessment.isnull().sum()
# Out:
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64

# %%
studAssessment['is_banked'].value_counts()
# Out:
# 0    172003
# 1      1909
# Name: is_banked, dtype: int64

# %%
studAssessment.describe()
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173912.000000  1.739120e+05   173912.000000  173912.000000
# mean    26553.803556  7.051507e+05      116.032942       0.010977
# std      8829.784254  5.523952e+05       71.484148       0.104194
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044290e+05       51.000000       0.000000
# 50%     25359.000000  5.852080e+05      116.000000       0.000000
# 75%     34883.000000  6.344980e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173739.000000
# mean       75.799573
# std        18.798107
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %%
studAssessment['score'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Assessment info

# %%
assessment = pd.read_csv('./data/assessments.csv')
assessment
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           AAA             2013J           1752             TMA   19.0
# 1           AAA             2013J           1753             TMA   54.0
# 2           AAA             2013J           1754             TMA  117.0
# 3           AAA             2013J           1755             TMA  166.0
# 4           AAA             2013J           1756             TMA  215.0
# ..          ...               ...            ...             ...    ...
# 201         GGG             2014J          37443             CMA  229.0
# 202         GGG             2014J          37435             TMA   61.0
# 203         GGG             2014J          37436             TMA  124.0
# 204         GGG             2014J          37437             TMA  173.0
# 205         GGG             2014J          37444            Exam  229.0
#
#      weight
# 0      10.0
# 1      20.0
# 2      20.0
# 3      20.0
# 4      30.0
# ..      ...
# 201     0.0
# 202     0.0
# 203     0.0
# 204     0.0
# 205   100.0
#
# [206 rows x 6 columns]

# %%
assessment.isnull().sum()
# Out:
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64

# %%
assessment['assessment_type'].value_counts()
# Out:
# TMA     106
# CMA      76
# Exam     24
# Name: assessment_type, dtype: int64

# %%
assessment.query('code_module=="AAA" and code_presentation=="2013J"')
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0
# 5         AAA             2013J           1757            Exam    NaN   100.0

# %%
assessment['date'].value_counts().index
# Out:
# Float64Index([222.0, 229.0, 241.0, 236.0, 227.0, 166.0,  19.0, 117.0, 131.0,
#                47.0, 124.0,  54.0, 152.0,  68.0, 200.0,  33.0, 159.0,  96.0,
#               207.0,  53.0,  89.0, 173.0,  61.0,  25.0, 215.0, 158.0,  82.0,
#                24.0, 151.0, 187.0,  18.0, 116.0,  67.0,  52.0, 194.0, 208.0,
#               235.0,  32.0, 111.0,  23.0,  12.0, 214.0, 123.0,  88.0, 110.0,
#               171.0,  79.0, 165.0,  40.0, 114.0, 199.0, 206.0,  87.0, 129.0,
#               170.0, 136.0,  41.0, 144.0,  51.0, 261.0, 201.0, 240.0,  20.0,
#               146.0, 137.0, 102.0, 195.0,  62.0, 149.0, 109.0, 228.0,  94.0,
#                81.0,  74.0],
#              dtype='float64')

# %% [markdown]
# # Student register

# %%
studRegister = pd.read_csv('./data/studentRegistration.csv')
studRegister
# Out:
#       code_module code_presentation  id_student  date_registration  \
# 0             AAA             2013J       11391             -159.0
# 1             AAA             2013J       28400              -53.0
# 2             AAA             2013J       30268              -92.0
# 3             AAA             2013J       31604              -52.0
# 4             AAA             2013J       32885             -176.0
# ...           ...               ...         ...                ...
# 32588         GGG             2014J     2640965               -4.0
# 32589         GGG             2014J     2645731              -23.0
# 32590         GGG             2014J     2648187             -129.0
# 32591         GGG             2014J     2679821              -49.0
# 32592         GGG             2014J     2684003              -28.0
#
#        date_unregistration
# 0                      NaN
# 1                      NaN
# 2                     12.0
# 3                      NaN
# 4                      NaN
# ...                    ...
# 32588                  NaN
# 32589                  NaN
# 32590                  NaN
# 32591                101.0
# 32592                  NaN
#
# [32593 rows x 5 columns]

# %%
studRegister.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# date_registration         45
# date_unregistration    22521
# dtype: int64

# %% [markdown]
# # Courses

# %%
courses = pd.read_csv('./data/courses.csv')
courses
# Out:
#    code_module code_presentation  module_presentation_length
# 0          AAA             2013J                         268
# 1          AAA             2014J                         269
# 2          BBB             2013J                         268
# 3          BBB             2014J                         262
# 4          BBB             2013B                         240
# 5          BBB             2014B                         234
# 6          CCC             2014J                         269
# 7          CCC             2014B                         241
# 8          DDD             2013J                         261
# 9          DDD             2014J                         262
# 10         DDD             2013B                         240
# 11         DDD             2014B                         241
# 12         EEE             2013J                         268
# 13         EEE             2014J                         269
# 14         EEE             2014B                         241
# 15         FFF             2013J                         268
# 16         FFF             2014J                         269
# 17         FFF             2013B                         240
# 18         FFF             2014B                         241
# 19         GGG             2013J                         261
# 20         GGG             2014J                         269
# 21         GGG             2014B                         241

# %%
courses.isnull().sum()
# Out:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64

# %% [markdown]
# # Student VLE

# %%
studvle = pd.read_csv('./data/studentVle.csv')
studvle
# Out:
#          code_module code_presentation  id_student  id_site  date  sum_click
# 0                AAA             2013J       28400   546652   -10          4
# 1                AAA             2013J       28400   546652   -10          1
# 2                AAA             2013J       28400   546652   -10          1
# 3                AAA             2013J       28400   546614   -10         11
# 4                AAA             2013J       28400   546714   -10          1
# ...              ...               ...         ...      ...   ...        ...
# 10655275         GGG             2014J      675811   896943   269          3
# 10655276         GGG             2014J      675578   896943   269          1
# 10655277         GGG             2014J      654064   896943   269          3
# 10655278         GGG             2014J      654064   896939   269          1
# 10655279         GGG             2014J      654064   896939   269          1
#
# [10655280 rows x 6 columns]

# %%
studvle.query('code_module=="AAA" and code_presentation=="2013J" and id_student=="28400"')[['id_site', 'sum_click']].groupby('id_site').agg({'id_site':'count', 'sum_click':sum})
# Out:
# C:\Users\polit\anaconda3\envs\Tensorflow\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Empty DataFrame
# Columns: [id_site, sum_click]
# Index: []

# %%
studvle.isnull().sum()
# Out:
# code_module          0
# code_presentation    0
# id_student           0
# id_site              0
# date                 0
# sum_click            0
# dtype: int64

# %% [markdown]
# # VLE

# %%
vle = pd.read_csv('./data/vle.csv')
vle
# Out:
#       id_site code_module code_presentation activity_type  week_from  week_to
# 0      546943         AAA             2013J      resource        NaN      NaN
# 1      546712         AAA             2013J     oucontent        NaN      NaN
# 2      546998         AAA             2013J      resource        NaN      NaN
# 3      546888         AAA             2013J           url        NaN      NaN
# 4      547035         AAA             2013J      resource        NaN      NaN
# ...       ...         ...               ...           ...        ...      ...
# 6359   897063         GGG             2014J      resource        NaN      NaN
# 6360   897109         GGG             2014J      resource        NaN      NaN
# 6361   896965         GGG             2014J     oucontent        NaN      NaN
# 6362   897060         GGG             2014J      resource        NaN      NaN
# 6363   897100         GGG             2014J      resource        NaN      NaN
#
# [6364 rows x 6 columns]

# %%
vle['activity_type'].value_counts()
# Out:
# resource          2660
# subpage           1055
# oucontent          996
# url                886
# forumng            194
# quiz               127
# page               102
# oucollaborate       82
# questionnaire       61
# ouwiki              49
# dataplus            28
# externalquiz        26
# homepage            22
# ouelluminate        21
# glossary            21
# dualpane            20
# repeatactivity       5
# htmlactivity         4
# sharedsubpage        3
# folder               2
# Name: activity_type, dtype: int64

# %%
vle.isnull().sum()
# Out:
# id_site                 0
# code_module             0
# code_presentation       0
# activity_type           0
# week_from            5243
# week_to              5243
# dtype: int64

# %%
vle.query('week_from != "nan"')
# Out:
#       id_site code_module code_presentation activity_type  week_from  week_to
# 0      546943         AAA             2013J      resource        NaN      NaN
# 1      546712         AAA             2013J     oucontent        NaN      NaN
# 2      546998         AAA             2013J      resource        NaN      NaN
# 3      546888         AAA             2013J           url        NaN      NaN
# 4      547035         AAA             2013J      resource        NaN      NaN
# ...       ...         ...               ...           ...        ...      ...
# 6359   897063         GGG             2014J      resource        NaN      NaN
# 6360   897109         GGG             2014J      resource        NaN      NaN
# 6361   896965         GGG             2014J     oucontent        NaN      NaN
# 6362   897060         GGG             2014J      resource        NaN      NaN
# 6363   897100         GGG             2014J      resource        NaN      NaN
#
# [6364 rows x 6 columns]

# %%
vle.query('code_module=="AAA" and code_presentation=="2013J"')
# Out:
#      id_site code_module code_presentation activity_type  week_from  week_to
# 0     546943         AAA             2013J      resource        NaN      NaN
# 1     546712         AAA             2013J     oucontent        NaN      NaN
# 2     546998         AAA             2013J      resource        NaN      NaN
# 3     546888         AAA             2013J           url        NaN      NaN
# 4     547035         AAA             2013J      resource        NaN      NaN
# ..       ...         ...               ...           ...        ...      ...
# 206   547002         AAA             2013J      resource        NaN      NaN
# 207   547038         AAA             2013J      resource        NaN      NaN
# 208   546647         AAA             2013J       forumng        NaN      NaN
# 209   546900         AAA             2013J           url        NaN      NaN
# 210   546681         AAA             2013J     oucontent        1.0      1.0
#
# [211 rows x 6 columns]

# %%
vle.query('code_module=="AAA" and code_presentation=="2013J"')['activity_type'].value_counts()
# Out:
# resource         95
# oucontent        68
# url              18
# forumng          15
# subpage           6
# dataplus          4
# glossary          2
# oucollaborate     2
# homepage          1
# Name: activity_type, dtype: int64

# %%
vle['activity_type'].value_counts().index
# Out:
# Index(['resource', 'subpage', 'oucontent', 'url', 'forumng', 'quiz', 'page',
#        'oucollaborate', 'questionnaire', 'ouwiki', 'dataplus', 'externalquiz',
#        'homepage', 'ouelluminate', 'glossary', 'dualpane', 'repeatactivity',
#        'htmlactivity', 'sharedsubpage', 'folder'],
#       dtype='object')
